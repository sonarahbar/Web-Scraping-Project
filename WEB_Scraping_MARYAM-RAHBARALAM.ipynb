# %% [markdown]
# # Scraping project
# ## Maryam Rahbaralam
# In this project we want to:
# 1) Scrape and crawl an eyeglasses website with parse HTML using Beautiful Soup
# 2) Set up multiprocessing to execute the web scraper in parallel
# This website has different eyeglasses with different specifications such as: Brand, Price, Color, Weight, Material.

# %%
#First of all we are going to import libraries.
from bs4 import BeautifulSoup
import requests
import pandas as pd
from time import perf_counter, sleep
import time
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor, as_completed
from multiprocessing import Pool
import re
import csv
from threading import Thread
from queue import Queu

# %%
def get_soup(url):
    #Making an HTTP request and parsing
    #And creating a BeautifulSoup(soup) object with the BeautifulSoup function. 
    page=requests.get(url)
    results=page.content
    soup=BeautifulSoup(results,"lxml")
    return soup

# %%
def parse_eyeglasses(url):
    #Extracting the information of all glasses including each link 
    #Then Obtaining the information of each glass
    soup=get_soup(url)
    items=soup.find_all("div",{'class':'item-image'}) 
    eyeglasses_list=[]
    count = 0
    for i in items:
        eyeglasses=i.find('a',{'class':'event-list-link'})
        eyeglasses_link=eyeglasses.get("href") 
        glasses_info = get_info(url + eyeglasses_link) 
        eyeglasses_list.append(glasses_info)

    return eyeglasses_list

# %%
def get_info(url):
    #Extracting the Information of glasses: 1)Brand 2)Price 3)color 4)Weight 5)Material 
    soup=get_soup(url)
    
    item= soup.find("h1",{"itemprop":"name"}).next
    Brand=re.sub('\s+', '', item)
    
    item1= soup.find("meta",{"itemprop":"price"})  
    Price=item1.get("content")
   
    item2=soup.find("i",{"class":"im im-details im-color"}).next
    Color=re.sub('Color: ', '', item2)
    
    item3=soup.find("i",{"class":"im im-details im-weight"}).next
    Weight =re.findall('\\d+', item3)[0]
    
    item4=soup.find("a",{"data-event-label":"Materials"})
    temp=item4.get("href")
    Material = re.sub('/eyeglasses/', '', temp)
    
  
    return Brand, Price, Color, Weight, Material

# %%
#getting the information of all glasses from the website and measuring the scraping time
url='https://www.eyebuydirect.com/eyeglasses'
toc=time.time()
glasses_info=parse_eyeglasses(url)
tic=time.time()
print("Scraping time: "+str(round(tic-toc,1))+"s")
# Out:
# Scraping time: 46.6s

# %%
#Changing the list of glasses into a dataframe(df)
df=pd.DataFrame(glasses_info)
df.columns = ['Brand','Price','Color',
                     'Weight','Material']
#Generating the CSV file
df.to_csv('glasses_info.csv')
df.head(len(glasses_info))
# Out:
#            Brand Price            Color Weight Material
# 0       StMichel    32           Golden     15    metal
# 1       Chilling    16            Black     11  plastic
# 2        Bristol    20      Matte Black     21  acetate
# 3       Dialogue    15        Aubergine      8  plastic
# 4    NottingHill    30      Blue Floral     18  acetate
# 5        Chillax    16         Tortoise     12    metal
# 6        Hepburn    40      Clear/White     18  acetate
# 7       Botanist    30       Gray Brown     15  acetate
# 8           Muse    16      Blue Floral     13  plastic
# 9          Mandi    33             Teal     19  acetate
# 10      Daydream    30     Brown Golden     12    metal
# 11   Ghostwriter    19      Matte Black     13    metal
# 12          Aura    70        Champagne     17  acetate
# 13       Morning    33         Tortoise     18  acetate
# 14   Inscription    29           Bronze     13    metal
# 15      Blizzard    29           Black      23  acetate
# 16         Prism    65      Translucent     16  acetate
# 17         Albee    19     Black Bronze     15    metal
# 18       Wistful    32           Coffee     11    metal
# 19      PaloAlto    33           Silver     13    metal
# 20       Candela    59      Blue Floral     21  acetate
# 21        Dublin    19      Matte Black     18    metal
# 22           Her    42            Black     19  acetate
# 23      Discover    29           Bronze     19    metal
# 24    Lightworks    25      Pink Floral     17    metal
# 25        Ledger    32           Golden     14    metal
# 26       Annabel    52             Pink     20  acetate
# 27      Sequence    70   Amber Tortoise     16  acetate
# 28        Hubris    25     Black Floral     10  plastic
# 29        Comity    35      Light Green     18  acetate
# 30          Milo     9      Matte Black     11  plastic
# 31      November     9      Matte Black     11  plastic
# 32          Days     9     Matte Floral     10  plastic
# 33        Versus     9      Matte Black     10  plastic
# 34        Bandon     6            Black     12  plastic
# 35       Firefly     9           Brown      10  plastic
# 36        Glider     9            Black     10  plastic
# 37        Daphne    16            White     15  plastic
# 38         Drums     6             Red      10  plastic
# 39         Furox    19         Gunmetal     13    metal
# 40        Madras     9            Black      9  plastic
# 41         Naomi    15            Black     10    metal
# 42  InstantCrush    15              Red     14  plastic
# 43     Structure     9            Black      8  plastic
# 44      Delaware     9   Matte Burgundy     12  plastic
# 45        Yokote    22      Matte Black     17    metal
# 46     Chistopol     9            Black     13    metal
# 47         Danny     9     Black/White      12  plastic
# 48      Portrait    15   Black Tortoise     10  plastic
# 49         Beads     9       Matte Gray     11  plastic
# 50     Character    15   Black Tortoise     13  plastic
# 51        Escape    32       Matte Pink     18  acetate
# 52        Apollo     6       Matte Gray     13  plastic
# 53      Dutchess     9      Matte Black     10  plastic
# 54       Coexist    22         Tortoise     17    metal
# 55          Soul     9            Black     10  plastic
# 56        Robbie     6      Black/White     12  plastic
# 57       Jasmine    35            Black     16  acetate
# 58    BrightSide     9   Brown Tortoise     10  plastic
# 59       Central     9      Matte Black     14  plastic

# %% [markdown]
# # Parallelism using Thread library of Python
#
# The total scraping time is about 38.3s. We are going to use an efficient way to speed up and decrease this time by parallel processing via the multithreading library.
# To start we have to get the links of all the pages in the site.

# %%
def parse_eyeglasses_url_list(url):
   #Scraping and Parsing only the main page
    
    soup=get_soup(url)
    items=soup.find_all("div",{'class':'item-image'})
    eyeglasses_url_list=[]
    count = 0
    for i in items:
        eyeglasses=i.find('a',{'class':'event-list-link'})
        eyeglasses_link=eyeglasses.get("href") 
        eyeglasses_url_list.append(url + eyeglasses_link)

    return eyeglasses_url_list

# %%
def get_info(url):
    #Scraping and Parsing the other url's of all the different pages
    soup=get_soup(url)
    
    item= soup.find("h1",{"itemprop":"name"}).next
    Brand=re.sub('\s+', '', item)
    
    item1= soup.find("meta",{"itemprop":"price"})  
    Price=item1.get("content")
   
    item2=soup.find("i",{"class":"im im-details im-color"}).next
    Color=re.sub('Color: ', '', item2)
    
    item3=soup.find("i",{"class":"im im-details im-weight"}).next
    Weight =re.findall('\\d+', item3)[0]
    
    item4=soup.find("a",{"data-event-label":"Materials"})
    temp=item4.get("href")
    Material = re.sub('/eyeglasses/', '', temp)
    
  
    return Brand, Price, Color, Weight, Material

# %%
def parallel_scraper(urls):
    #Defining scraper and the queue of the urls
    eyeglasses_list = []
    queue_list = Queue()
    
    for url in urls:
        queue_list.put(url)
        
    for i in range(20):
        #Using 20 threads 
        t = Thread(target = scraper_thread, args = (queue_list, eyeglasses_list))
        t.daemon = True
        t.start()
    queue_list.join()
    return eyeglasses_list

def scraper_thread(queue_list, eyeglasses_list):
    # Given the url list and queues, we divide them between different threads 
    while not queue_list.empty():
        url = queue_list.get()
        glasses_info=get_info(url)
        eyeglasses_list.append(glasses_info)
        queue_list.task_done() #move to another task

# %%
url='https://www.eyebuydirect.com/eyeglasses'
toc=time.time()
eyeglasses_url_list = parse_eyeglasses_url_list(url)
glasses_info_par = parallel_scraper(eyeglasses_url_list)
tic=time.time()
print("Scraping time: "+str(round(tic-toc,1))+"s")
# Out:
# Scraping time: 6.6s

# %% [markdown]
# # Conclusion
# ### We can see that the Scraping time is decreased by almost 6 times :)

# %%
df_par=pd.DataFrame(glasses_info_par)
df_par.columns = ['Brand','Price','Color',
                     'Weight','Material']
df_par.head(len(results))
# Out:
#            Brand Price            Color Weight Material
# 0       Chilling    16            Black     11  plastic
# 1        Chillax    16         Tortoise     12    metal
# 2        Hepburn    40      Clear/White     18  acetate
# 3       StMichel    32           Golden     15    metal
# 4       Dialogue    15        Aubergine      8  plastic
# 5           Muse    16      Blue Floral     13  plastic
# 6       PaloAlto    33           Silver     13    metal
# 7          Prism    65      Translucent     16  acetate
# 8    NottingHill    30      Blue Floral     18  acetate
# 9        Bristol    20      Matte Black     21  acetate
# 10         Albee    19     Black Bronze     15    metal
# 11      Daydream    30     Brown Golden     12    metal
# 12      Botanist    30       Gray Brown     15  acetate
# 13       Morning    33         Tortoise     18  acetate
# 14         Mandi    33             Teal     19  acetate
# 15          Aura    70        Champagne     17  acetate
# 16      Blizzard    29           Black      23  acetate
# 17   Inscription    29           Bronze     13    metal
# 18   Ghostwriter    19      Matte Black     13    metal
# 19       Wistful    32           Coffee     11    metal
# 20        Dublin    19      Matte Black     18    metal
# 21    Lightworks    25      Pink Floral     17    metal
# 22      Discover    29           Bronze     19    metal
# 23           Her    42            Black     19  acetate
# 24       Candela    59      Blue Floral     21  acetate
# 25        Ledger    32           Golden     14    metal
# 26      Sequence    70   Amber Tortoise     16  acetate
# 27       Annabel    52             Pink     20  acetate
# 28          Milo     9      Matte Black     11  plastic
# 29        Comity    35      Light Green     18  acetate
# 30        Hubris    25     Black Floral     10  plastic
# 31          Days     9     Matte Floral     10  plastic
# 32       Firefly     9           Brown      10  plastic
# 33      November     9      Matte Black     11  plastic
# 34        Versus     9      Matte Black     10  plastic
# 35        Glider     9            Black     10  plastic
# 36        Bandon     6            Black     12  plastic
# 37         Drums     6             Red      10  plastic
# 38        Daphne    16            White     15  plastic
# 39         Furox    19         Gunmetal     13    metal
# 40        Madras     9            Black      9  plastic
# 41         Naomi    15            Black     10    metal
# 42  InstantCrush    15              Red     14  plastic
# 43     Structure     9            Black      8  plastic
# 44      Delaware     9   Matte Burgundy     12  plastic
# 45        Yokote    22      Matte Black     17    metal
# 46         Danny     9     Black/White      12  plastic
# 47     Chistopol     9            Black     13    metal
# 48         Beads     9       Matte Gray     11  plastic
# 49      Portrait    15   Black Tortoise     10  plastic
# 50     Character    15   Black Tortoise     13  plastic
# 51      Dutchess     9      Matte Black     10  plastic
# 52        Escape    32       Matte Pink     18  acetate
# 53        Robbie     6      Black/White     12  plastic
# 54        Apollo     6       Matte Gray     13  plastic
# 55          Soul     9            Black     10  plastic
# 56       Coexist    22         Tortoise     17    metal
# 57       Jasmine    35            Black     16  acetate
# 58    BrightSide     9   Brown Tortoise     10  plastic
# 59       Central     9      Matte Black     14  plastic
